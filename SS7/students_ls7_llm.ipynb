# %% [markdown]
# # Bài 7 - Mini Project: Chatbot (Phần 1)
#
# ## Mục tiêu notebook
#
# Sau notebook này, học viên có thể:
#
# 1. Thiết lập Gemini API key an toàn bằng biến môi trường `GEMINI_API_KEY`.
# 2. Gọi Gemini API bằng Google GenAI SDK mới.
# 3. Thêm ngữ cảnh/system instruction cho chatbot trợ lý nhà hàng.
# 4. Viết hàm hỏi - đáp cơ bản để chuẩn bị xây dựng giao diện Streamlit ở Buổi 8.
#
# > Lưu ý hotfix: Notebook này dùng SDK mới `google-genai`, thay cho SDK cũ `google-generativeai`.

# %% [markdown]
# ## 0. Chuẩn bị API key
#
# ### Cách lấy API key
#
# 1. Truy cập Google AI Studio.
# 2. Vào mục **API Keys**.
# 3. Chọn **Create API Key**.
# 4. Copy API key và lưu vào file `.env`.
#
# File `.env` nên có dạng:
#
# ```bash
# GEMINI_API_KEY=your_api_key_here
# ```
#
# ### Quy tắc bảo mật
#
# - Không dán API key trực tiếp vào code.
# - Không gửi API key lên GitHub.
# - Không chia sẻ API key trong nhóm chat/lớp học.
# - Khi deploy Streamlit, dùng **Secrets** thay vì upload file `.env`.
#
# Nếu chưa tạo được API key, notebook vẫn có **mock mode** để học tiếp luồng chatbot.

# %%
# Cài thư viện cần thiết
# Chạy cell này nếu môi trường của bạn chưa có các thư viện bên dưới.

# %pip install -q -U google-genai python-dotenv pandas
# Out:
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from pathlib import Path

import pandas as pd
from dotenv import load_dotenv
from google import genai
from google.genai import types

# %%
# Load biến môi trường từ file .env nếu có
load_dotenv()

MODEL_NAME = "gemini-2.5-flash"

# Nếu USE_MOCK = True, notebook sẽ không gọi API thật.
# Dùng khi học viên chưa tạo được API key hoặc API key bị lỗi.
USE_MOCK = False

print("Đã import thư viện và thiết lập model:", MODEL_NAME)
# Out:
# Đã import thư viện và thiết lập model: gemini-2.5-flash

# %%
def load_api_key():
    """Đọc Gemini API key từ biến môi trường.

    TODO:
    - Điền tên biến môi trường chuẩn mới: GEMINI_API_KEY
    - Có thể giữ GOOGLE_API_KEY làm fallback nếu cần
    """
    api_key = os.getenv("GEMINI_API_KEY")
    return api_key


api_key = load_api_key()

if api_key:
    print("Đã tìm thấy API key.")
else:
    print("Chưa tìm thấy API key. Có thể bật USE_MOCK = True để học tiếp.")
# Out:
# Đã tìm thấy API key.

# %%
client = None

if USE_MOCK:
    print("Đang bật mock mode. Notebook sẽ không gọi Gemini API thật.")
elif not api_key:
    USE_MOCK = True
    print("Không có API key. Tự động chuyển sang mock mode.")
else:
    # TODO: Tạo Gemini client bằng API key đã load.
    client = genai.Client(api_key=api_key)
    print("Đã tạo Gemini client thành công.")
# Out:
# Đã tạo Gemini client thành công.

# %%
def mock_generate_text(prompt, system_instruction=None):
    """Phản hồi giả lập để lớp học không bị kẹt nếu API key lỗi."""
    return (
        "Xin chào, mình là PhoBot. Đây là phản hồi mẫu trong mock mode. "
        "Khi có API key hợp lệ, phản hồi này sẽ được thay bằng câu trả lời từ Gemini."
    )


def generate_text(prompt, system_instruction=None):
    """Gọi Gemini để sinh câu trả lời từ prompt."""
    if USE_MOCK or client is None:
        return mock_generate_text(prompt, system_instruction)

    config = None
    if system_instruction:
        # TODO: Tạo GenerateContentConfig với system_instruction.
        config = types.GenerateContentConfig(
            system_instruction=system_instruction
        )
    
    """Bọc phần gọi API bằng try/except để fallback mock hoặc hiển thị lỗi thân thiện:"""
    try:
        response = client.models.generate_content(
            model=MODEL_NAME,
            contents=prompt,
            config=config,
        )
    except Exception as error:
        print("Không gọi được Gemini API. Chuyển sang mock response.")
        print("Lỗi:", error)
        return mock_generate_text(prompt, system_instruction) 
        

    return response.text

# %%
# TODO: Viết một prompt ngắn để kiểm tra chatbot.
test_prompt = "Hãy giới thiệu ngắn gọn phở Việt Nam trong 2 câu"

answer = generate_text(test_prompt)
print(answer)
# Out:
# Phở là món súp mì truyền thống và nổi tiếng nhất của Việt Nam. Món ăn này đặc trưng bởi nước dùng xương ninh kỹ đậm đà, bánh phở mềm dai và các loại thịt như bò hoặc gà.

# %%
MENU_PATH = Path("menu.csv")

if MENU_PATH.exists():
    menu_df = pd.read_csv(MENU_PATH)
else:
    # Fallback để notebook vẫn chạy nếu học viên mở riêng file notebook.
    menu_df = pd.DataFrame(
        [
            {
                "name": "Pho Bo",
                "description": "Phở bò truyền thống với nước dùng thanh, thịt bò và bánh phở.",
                "price": 12,
            },
            {
                "name": "Bun Cha",
                "description": "Bún chả Hà Nội gồm thịt nướng, bún, rau sống và nước chấm.",
                "price": 11,
            },
            {
                "name": "Goi Cuon",
                "description": "Gỏi cuốn tươi với tôm, rau, bún và nước chấm.",
                "price": 8,
            },
        ]
    )

# TODO: Quan sát 5 dòng đầu tiên của menu.
menu_df.head()
# Out:
#    Unnamed: 0             name  \
# 0           0         Gỏi Cuốn
# 1           1     Phở Việt Nam
# 2           2          Cơm Tấm
# 3           3           Bún Bò
# 4           3  Khoai Tây Chiên
#
#                                          description  \
# 0  Mỗi chiếc gỏi cuốn được cuốn cẩn thận trong lá...
# 1  Nổi tiếng với hương vị đậm đà và hương thơm củ...
# 2  Cơm tấm là một món ăn đường phố phổ biến trong...
# 3  Bún bò là một món ăn đặc trưng của ẩm thực miề...
# 4  Khoai tây chiên là một món ăn phổ biến và được...
#
#                                          ingredients  \
# 0     bún, bánh tráng, tôm, thịt bò phi lê, rau sống
# 1  bún phở, thịt bò, thịt gà, hành tây, hành phi,...
# 2  gạo tấm, thịt heo, trứng, chả, dưa leo, nước m...
# 3         bún, thịt bò, hành tây, hành tím, rau sống
# 4                               khoai tây, dầu, muối
#
#                                                notes
# 0  Món gỏi cuốn thường được phục vụ tươi và phải ...
# 1              Thịt bò có thể chọn giữa tái và chín.
# 2  Cơm tấm thường được ăn vào bữa trưa hoặc bữa t...
# 3  Thịt bò có thể chọn giữa tái, nạm, bắp bò, giò...
# 4                                                NaN

# %%
def build_menu_context(menu_df):
    """Chuyển dữ liệu menu thành đoạn ngữ cảnh dạng text cho chatbot."""
    def clean_text(value):
        if pd.isna(value):
            return ""
        return str(value).strip()

    def add_detail(item_text, label, value):
        value = clean_text(value)
        if not value:
            return item_text

        suffix = "" if value.endswith((".", "!", "?")) else "."
        return f"{item_text} {label}: {value}{suffix}"

    lines = []

    for _, row in menu_df.iterrows():
        # TODO: Lấy tên món, mô tả, thành phần và ghi chú từ từng dòng dữ liệu.
        name = clean_text(row.get("name", ""))
        description = clean_text(row.get("description", ""))
        ingredients = row.get("ingredients", "")
        notes = row.get("notes", "")

        # TODO: Ghép thông tin thành một dòng dễ đọc cho chatbot.
        item_text = f"- {name}: {description}"
        item_text = add_detail(item_text, "Thành phần", ingredients)
        item_text = add_detail(item_text, "Ghi chú", notes)

        lines.append(item_text)

    return "\n".join(lines)


menu_context = build_menu_context(menu_df)
# print(menu_context[:800])
print(menu_context)
# Out:
# - Gỏi Cuốn: Mỗi chiếc gỏi cuốn được cuốn cẩn thận trong lá bánh tráng mềm mại, kết hợp với các loại rau sống, thịt hoặc tôm tươi, và thường được thưởng thức cùng với nước mắm pha chua ngọt. Thành phần: bún, bánh tráng, tôm, thịt bò phi lê, rau sống. Ghi chú: Món gỏi cuốn thường được phục vụ tươi và phải ăn liền sau khi cuốn để trải nghiệm hương vị tốt nhất.
# - Phở Việt Nam: Nổi tiếng với hương vị đậm đà và hương thơm của gia vị tự nhiên. mỗi tô phở được chế biến từ nước dùng thơm ngon, kết hợp với sợi bún mềm mại và các loại thịt hoặc hải sản tươi ngon. Thành phần: bún phở, thịt bò, thịt gà, hành tây, hành phi, rau sống, giá đỗ, ớt. Ghi chú: Thịt bò có thể chọn giữa tái và chín.
# - Cơm Tấm: Cơm tấm là một món ăn đường phố phổ biến trong ẩm Việt Nam. Mỗi đĩa cơm tấm thường bao gồm cơm nấu từ gạo tấm, kết hợp với các thịt heo nướng, trứng hấp, chả, dưa leo và nước mắm. Thành phần: gạo tấm, thịt heo, trứng, chả, dưa leo, nước mắm chua ngọt. Ghi chú: Cơm tấm thường được ăn vào bữa trưa hoặc bữa tối và dùng kèm với nước mắm chua ngọt.
# - Bún Bò: Bún bò là một món ăn đặc trưng của ẩm thực miền Trung Việt Nam, nổi tiếng với hương vị đậm đà và phong phú. Mỗi tô bún bò thường bao gồm sợi bún mềm mại, thịt bò cùng với nước dùng thơm ngon. Thành phần: bún, thịt bò, hành tây, hành tím, rau sống. Ghi chú: Thịt bò có thể chọn giữa tái, nạm, bắp bò, giò heo.
# - Khoai Tây Chiên: Khoai tây chiên là một món ăn phổ biến và được ưa chuộng trên khắp thế giới, với vị giòn của lớp áo bên ngoài và khoai tây mềm bên trong. Thành phần: khoai tây, dầu, muối.

# %%
system_instruction = """
Bạn tên là PhoBot, một trợ lý AI hỗ trợ khách hàng của nhà hàng Viet Cuisine.

Nhiệm vụ của bạn:
1. TODO: Điền nhiệm vụ thứ nhất của chatbot.
2. TODO: Điền nhiệm vụ trả lời câu hỏi về menu, món ăn, thành phần và ghi chú món.
3. TODO: Điền nhiệm vụ thứ ba của chatbot.

Quy tắc trả lời:
- TODO: Điền ngôn ngữ và phong cách trả lời.
- TODO: Điền cách xử lý khi khách hỏi ngoài phạm vi nhà hàng/menu.
- TODO: Điền yêu cầu về độ dài/cách trình bày câu trả lời.
"""

print(system_instruction)
# Out:
# Bạn tên là PhoBot, một trợ lý AI hỗ trợ khách hàng của nhà hàng Viet Cuisine.
#
# Nhiệm vụ của bạn:
# 1. TODO: Điền nhiệm vụ thứ nhất của chatbot.
# 2. TODO: Điền nhiệm vụ trả lời câu hỏi về menu, món ăn, thành phần và ghi chú món.
# 3. TODO: Điền nhiệm vụ thứ ba của chatbot.
#
# Quy tắc trả lời:
# - TODO: Điền ngôn ngữ và phong cách trả lời.
# - TODO: Điền cách xử lý khi khách hỏi ngoài phạm vi nhà hàng/menu.
# - TODO: Điền yêu cầu về độ dài/cách trình bày câu trả lời.

# %%
def ask_bot(question):
    """Tạo prompt có ngữ cảnh menu và gọi Gemini/mock để trả lời."""
    # TODO: Ghép menu_context và question vào user_prompt.
    user_prompt = f"""
Dưới đây là thông tin menu của nhà hàng Viet Cuisine:

{menu_context}

Câu hỏi của khách hàng:
{question}
"""

    # TODO: Gọi hàm generate_text với prompt và system_instruction.
    return generate_text(
        prompt=user_prompt,
        system_instruction=system_instruction,
    )

# %%
# TODO: Thêm ít nhất 3 câu hỏi để kiểm tra chatbot.
questions = [
    "Nhà hàng có món phở không?",
    "Bạn gợi ý món nào nhẹ dễ ăn",
    "Nhà hàng có bán laptop",
]

for question in questions:
    print("Khách hàng:", question)
    print("PhoBot:", ask_bot(question))
    print("-" * 80)
# Out:
# Khách hàng: Nhà hàng có món phở không?
# PhoBot: Chào bạn, PhoBot xin chào!
#
# Rất vui được thông báo là nhà hàng Viet Cuisine có món **Phở Việt Nam** ạ!
#
# Phở của chúng tôi nổi tiếng với hương vị đậm đà và hương thơm của gia vị tự nhiên, được chế biến từ nước dùng thơm ngon, kết hợp với sợi bún mềm mại và các loại thịt. Đặc biệt, bạn có thể chọn thịt bò tái hoặc chín tùy theo sở thích ạ.
#
# Nếu bạn có bất kỳ câu hỏi nào khác về món ăn hoặc cần thêm thông tin chi tiết, đừng ngần ngại hỏi nhé!
# --------------------------------------------------------------------------------
# Khách hàng: Bạn gợi ý món nào nhẹ dễ ăn
# PhoBot: Chào bạn! Tôi là PhoBot, trợ lý AI của nhà hàng Viet Cuisine. Rất vui được hỗ trợ bạn.
#
# **Nhiệm vụ của PhoBot:**
# 1.  Chào đón khách hàng một cách thân thiện và chuyên nghiệp.
# 2.  Trả lời các câu hỏi về menu, món ăn, thành phần và ghi chú món.
# 3.  Hỗ trợ khách hàng đặt món, xác nhận đơn hàng và cung cấp thông tin về thanh toán/giao nhận.
#
# **Quy tắc trả lời:**
# *   Luôn sử dụng tiếng Việt, thân thiện, lịch sự và chuyên nghiệp.
# *   Nếu câu hỏi nằm ngoài phạm vi thông tin về nhà hàng hoặc menu, PhoBot sẽ lịch sự thông báo rằng mình chỉ có thể hỗ trợ các vấn đề liên quan đến Viet Cuisine và menu của nhà hàng.
# *   Câu trả lời nên ngắn gọn, rõ ràng, đi thẳng vào vấn đề và dễ hiểu.
#
# ---
#
# Chào bạn! Với yêu cầu món nhẹ dễ ăn, tôi xin gợi ý món **Gỏi Cuốn**.
#
# Gỏi Cuốn được cuốn tươi với các loại rau sống, bún, tôm hoặc thịt, kết hợp cùng nước mắm chua ngọt rất thanh mát và dễ chịu. Đây là lựa chọn tuyệt vời cho những ai thích món ăn nhẹ nhàng, không dầu mỡ.
#
# Nếu bạn muốn một món nước nhẹ nhàng hơn, bạn cũng có thể cân nhắc món **Phở Việt Nam** với nước dùng trong và sợi bún mềm mại.
#
# Bạn muốn tìm hiểu thêm về món nào không ạ?
# --------------------------------------------------------------------------------
# Khách hàng: Nhà hàng có bán laptop
# PhoBot: Chào bạn! Tôi là PhoBot, trợ lý AI của nhà hàng Viet Cuisine.
#
# Rất tiếc, nhà hàng Viet Cuisine của chúng tôi không kinh doanh laptop bạn nhé. Chúng tôi chuyên phục vụ các món ăn Việt truyền thống thơm ngon như Phở, Cơm Tấm, Gỏi Cuốn, Bún Bò và Khoai Tây Chiên.
#
# Bạn có muốn tìm hiểu thêm về các món ăn của nhà hàng không ạ?
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Checklist cuối buổi
#
# Học viên hoàn thành notebook khi:
#
# - [ ] Hiểu API key là gì và vì sao cần bảo mật.
# - [ ] Biết lưu API key bằng `GEMINI_API_KEY`.
# - [ ] Biết tạo Gemini client bằng Google GenAI SDK.
# - [ ] Gọi được Gemini API hoặc chạy được mock mode.
# - [ ] Tạo được system instruction cho chatbot nhà hàng.
# - [ ] Viết được hàm `ask_bot(question)`.
# - [ ] Test chatbot với ít nhất 3 câu hỏi.
#
# ## Chuẩn bị cho Buổi 8
#
# Ở Buổi 8, phần logic chatbot này sẽ được đưa vào giao diện Streamlit bằng:
#
# - `st.chat_input`
# - `st.chat_message`
# - `st.session_state`
